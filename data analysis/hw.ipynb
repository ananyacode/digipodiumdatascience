# %%
import matplotlib.pyplot as plt # basic graph
import numpy as np 
import pandas as pd
import seaborn as sns # advanced graph
import plotly.express as px # interactive graphs

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.set_theme?
# Out:
# Signature:
# sns.set_theme(
#     context='notebook',
#     style='darkgrid',
#     palette='deep',
#     font='sans-serif',
#     font_scale=1,
#     color_codes=True,
#     rc=None,
# )
# Docstring:
# Set aspects of the visual theme for all matplotlib and seaborn plots.
#
# This function changes the global defaults for all plots using the
# matplotlib rcParams system. The themeing is decomposed into several distinct
# sets of parameter values.
#
# The options are illustrated in the :doc:`aesthetics <../tutorial/aesthetics>`
# and :doc:`color palette <../tutorial/color_palettes>` tutorials.
#
# Parameters
# ----------
# context : string or dict
#     Scaling parameters, see :func:`plotting_context`.
# style : string or dict
#     Axes style parameters, see :func:`axes_style`.
# palette : string or sequence
#     Color palette, see :func:`color_palette`.
# font : string
#     Font family, see matplotlib font manager.
# font_scale : float, optional
# ...

# %%
sns.set_theme()
sns.relplot(
    data=iris,
    x="sepal_length", y="sepal_width",col='species',
    hue="species"
);
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#the col="species" parameter creates separate columns for each species of iris flowers
#hue="species" parameter color-codes the data points within each species

sns.relplot(
    data=iris, kind="line",
    x="petal_length", y="petal_width", col="species",  
    hue="species", style="species",
    facet_kws=dict(sharex=False),
)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(
    data=iris, kind="line",
    x="sepal_length", y="petal_length", col="species",
    hue="species", style="species",
)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# The regplot function combines a scatter plot with a linear regression model to estimate and display the linear relationship between the variables

# %% [markdown]
# The lmplot allows you to create multiple scatter plots with regression lines, each representing a different level of a categorical variable

# %% [markdown]
# FacetGrid is a powerful feature in Seaborn that allows you to create a grid of subplots (facets) based on one or more categorical variables

# %% [markdown]
# lmplot = regplot + facetgrid

# %%
sns.lmplot(data=iris, x="sepal_length", y="sepal_width", col="species", hue="species")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# -lmplot
# Combine regplot() and FacetGrid to plot multiple linear relationships in a dataset.
#
# jointplot
# Combine regplot() and JointGrid (when used with kind="reg").
#
# pairplot
# Combine regplot() and PairGrid (when used with kind="reg").
#
# residplot
# Plot the residuals of a linear regression model.

# %%
sns.displot(data=iris, x="sepal_width", col="species", kde=True)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=iris, x="petal_length", col="species", kde=True)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=iris, kind="ecdf", x="sepal_lenght", col="species", hue="species")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sns.displot(data=iris, kind="ecdf", x="sepal_lenght", col="species", hue="species")
#
# File ~/miniconda3/lib/python3.11/site-packages/seaborn/distributions.py:2125, in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2111 def displot(
#    2112     data=None, *,
#    2113     # Vector variables
#    (...)
#    2122     **kwargs,
#    2123 ):
# -> 2125     p = _DistributionFacetPlotter(
#    2126         data=data,
#    2127         variables=_DistributionFacetPlotter.get_semantics(locals())
#    2128     )
#    2130     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#    2132     _check_argument("kind", ["hist", "kde", "ecdf"], kind)
#
# ...

# %%
sns.catplot(data=iris, kind="swarm", x="sepal_length", y="sepal_width", hue="species")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 40.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 20.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.catplot(data=titanic, kind="violin", x="sex", y="pclass", hue="survived", split=True)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=titanic, kind="bar", x="pclass", y="survived", hue="class")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(data=titanic, x="age", y="fare", hue="class")

# %%
sns.pairplot(data=iris, hue="species")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.PairGrid(iris, hue="species", corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %%
sns.relplot(
    data=iris,
    x="sepal_length", y="sepal_width", hue="species"
)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="ticks", font_scale=1.25)
g = sns.relplot(
    data=iris,
    x="sepal_length", y="sepal_width", hue="species",
    palette="crest", marker="x", s=100,
)
g.set_axis_labels("sepal_length", "sepal_width", labelpad=10)
g.legend.set_title("iris")
g.figure.set_size_inches(6.5, 4.5)
g.ax.margins(.15)
g.despine(trim=True)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.set_theme?
# Out:
# Signature:
# sns.set_theme(
#     context='notebook',
#     style='darkgrid',
#     palette='deep',
#     font='sans-serif',
#     font_scale=1,
#     color_codes=True,
#     rc=None,
# )
# Docstring:
# Set aspects of the visual theme for all matplotlib and seaborn plots.
#
# This function changes the global defaults for all plots using the
# matplotlib rcParams system. The themeing is decomposed into several distinct
# sets of parameter values.
#
# The options are illustrated in the :doc:`aesthetics <../tutorial/aesthetics>`
# and :doc:`color palette <../tutorial/color_palettes>` tutorials.
#
# Parameters
# ----------
# context : string or dict
#     Scaling parameters, see :func:`plotting_context`.
# style : string or dict
#     Axes style parameters, see :func:`axes_style`.
# palette : string or sequence
#     Color palette, see :func:`color_palette`.
# font : string
#     Font family, see matplotlib font manager.
# font_scale : float, optional
# ...

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_theme(
    context='notebook',
    style='darkgrid',
    palette='deep',
    font='sans-serif',
    font_scale=1.2,
    color_codes=True,
    rc=None,
)

sns.relplot(data = tips, x = "total_bill",y='tip',col='time',hue ='smoker',style='smoker',size='size')
# relplot is used to create scatter plot that shows the relationship between total_bill and tip
# The hue parameter is used to color the points based on the sex column
# style parameter is used to differentiate points based on the time column.
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dots = sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
dots = sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
flights = sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
planets = sns.load_dataset("planets")
planets
# Out:
#                method  number  orbital_period   mass  distance  year
# 0     Radial Velocity       1      269.300000   7.10     77.40  2006
# 1     Radial Velocity       1      874.774000   2.21     56.95  2008
# 2     Radial Velocity       1      763.000000   2.60     19.84  2011
# 3     Radial Velocity       1      326.030000  19.40    110.62  2007
# 4     Radial Velocity       1      516.220000  10.50    119.47  2009
# ...               ...     ...             ...    ...       ...   ...
# 1030          Transit       1        3.941507    NaN    172.00  2006
# 1031          Transit       1        2.615864    NaN    148.00  2007
# 1032          Transit       1        3.191524    NaN    174.00  2007
# 1033          Transit       1        4.125083    NaN    293.00  2008
# 1034          Transit       1        4.187757    NaN    260.00  2008
#
# [1035 rows x 6 columns]

# %%
exercise = sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
dots = sns.load_dataset("dots")
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate",col='align',
    hue="choice",style="choice",
   facet_kws=dict(sharex=False),
)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %% [markdown]
# statistical estimations

# %%
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot?
# Out:
# Signature:
# sns.lmplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     col=None,
#     row=None,
#     palette=None,
#     col_wrap=None,
#     height=5,
#     aspect=1,
#     markers='o',
#     sharex=None,
#     sharey=None,
#     hue_order=None,
#     col_order=None,
#     row_order=None,
#     legend=True,
#     legend_out=None,
#     x_estimator=None,
#     x_bins=None,
#     x_ci='ci',
#     scatter=True,
#     fit_reg=True,
#     ci=95,
#     n_boot=1000,
#     units=None,
#     seed=None,
#     order=1,
#     logistic=False,
#     lowess=False,
#     robust=False,
#     logx=False,
#     x_partial=None,
#     y_partial=None,
#     truncate=True,
#     x_jitter=None,
#     y_jitter=None,
#     scatter_kws=None,
#     line_kws=None,
#     facet_kws=None,
# )
# Docstring:
# Plot data and regression model fits across a FacetGrid.
#
# This function combines :func:`regplot` and :class:`FacetGrid`. It is
# ...

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# lmplot- This function combines regplot() and FacetGrid.

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(data=tips, x="total_bill", col="time",kde=True)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=tips, kind="bar", x="day", y="total_bill", hue="smoker")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
penguins = sns.load_dataset("penguins")
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="bill_length_mm", hue="species")

# %%
sns.pairplot(data=penguins, hue="species")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(data=tips, hue="day")
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(
    data=penguins,
    x="bill_length_mm", y="bill_depth_mm", hue="body_mass_g"
)
# Out:
# /Users/ananyashukla/miniconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
anscombe = sns.load_dataset("anscombe")
anscombe
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 anscombe = sns.load_dataset("anscombe")
#       2 anscombe
#
# File ~/miniconda3/lib/python3.11/site-packages/seaborn/utils.py:588, in load_dataset(name, cache, data_home, **kws)
#     586         if name not in get_dataset_names():
#     587             raise ValueError(f"'{name}' is not one of the example datasets.")
# --> 588         urlretrieve(url, cache_path)
#     589     full_path = cache_path
#     590 else:
#
# File ~/miniconda3/lib/python3.11/urllib/request.py:241, in urlretrieve(url, filename, reporthook, data)
#     224 """
#     225 Retrieve a URL into a temporary location on disk.
#     226
#    (...)
#     237 data file as well as the resulting HTTPMessage object.
#     238 """
#     239 url_type, path = _splittype(url)
# --> 241 with contextlib.closing(urlopen(url, data)) as fp:
# ...

# %%
import seaborn as sns
sns.set_theme(style="ticks")


sns.lmplot(
    data=df, x="x", y="y", col="dataset", hue="dataset",
    col_wrap=2, palette="muted", ci=None,
    height=4, scatter_kws={"s": 50, "alpha": 1}
)
