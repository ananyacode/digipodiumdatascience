# %%
import matplotlib.pyplot as plt # basic graph
import numpy as np 
import pandas as pd
import seaborn as sns # advanced graph
import plotly.express as px # interactive graphs

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
print(titanic['survived'].unique())
print(titanic['pclass'].unique())
print(titanic['age'].unique())
# Out:
# [0 1]
# [3 1 2]
# [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.  ]

# %% [markdown]
# # categorial graphs
# - columns that have text are generally categorial
# - the first step is to count the number of unique values in column
# - the plot the count of each category
# - following charts are a good way to visualize data
#   - bar chart
#   - pie chart
#   - donut chart
#   - line chart
#   - area chart

# %%
survival_count = titanic['survived'].value_counts()
survival_count.plot(kind= 'pie',autopct='%.1f%%',title = 'Survival Rate' ); # autopct for percentage

# %%
survival_count.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'Survival Rate',
    labels = ['Survived','Not Survived'],
    colors = ['#66b3ff','#ff9999'],
    labeldistance = 1.1,
    wedgeprops = {
        'width': 0.5,
    }
);

# %%
sex_category = titanic['sex'].value_counts()
sex_category.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'Sex',
    labels = ['Male','Female'],
    colors = ['#66b3ff','#ff9999'],
    labeldistance = 1.1,
    wedgeprops = {
        'width': 0.5,
    }
);

# %%
pclass_category = titanic['pclass'].value_counts()
pclass_category.plot(
    kind = 'pie',
    autopct = '%.1f%%',
    title = 'pclass',
    labels = ['1','2','3'],
    colors = ['#66b3ff','#ff9999','#99ff99'],
    labeldistance = 1.1,
    wedgeprops = {
        'width': 0.5,
    }
);

# %%
sns.countplot(data =titanic,x='alive',hue='sex',);

# %%
sns.countplot?
# Out:
# Signature:
# sns.countplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     order=None,
#     hue_order=None,
#     orient=None,
#     color=None,
#     palette=None,
#     saturation=0.75,
#     width=0.8,
#     dodge=True,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead
# of quantitative, variable. The basic API and options are identical to those
# for :func:`barplot`, so you can compare counts across nested variables.
#
# Note that the newer :func:`histplot` function offers more functionality, although
# its default behavior is somewhat different.
#
# .. note::
#     This function always treats one of the variables as categorical and
#     draws data at ordinal positions (0, 1, ... n) on the relevant axis,
#     even when the data has a numeric or date type.
#
# ...

# %%
sns.countplot(data =titanic,x='alive',hue='pclass',);

# %%
sns.countplot(data =titanic,x='alive',hue='adult_male',);

# %%
sns.jointplot?
# Out:
# Signature:
# sns.jointplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     kind='scatter',
#     height=6,
#     ratio=5,
#     space=0.2,
#     dropna=False,
#     xlim=None,
#     ylim=None,
#     color=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     marginal_ticks=False,
#     joint_kws=None,
#     marginal_kws=None,
#     **kwargs,
# )
# Docstring:
# Draw a plot of two variables with bivariate and univariate graphs.
#
# This function provides a convenient interface to the :class:`JointGrid`
# class, with several canned plot kinds. This is intended to be a fairly
# lightweight wrapper; if you need more flexibility, you should use
# :class:`JointGrid` directly.
#
# Parameters
# ----------
# data : :class:`pandas.DataFrame`, :class:`numpy.ndarray`, mapping, or sequence
#     Input data structure. Either a long-form collection of vectors that can be
# ...

# %%
sns.jointplot(data=titanic,x='fare',y='age',kind='kde',color='g',hue = 'survived');

# %%
sns.jointplot(data=titanic,x='fare',y='age',kind='scatter',hue = 'survived');
